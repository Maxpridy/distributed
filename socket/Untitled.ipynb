# %%
import socket
import time
from collections import Counter


def add_two_dicts(x, y):
    return Counter(x) + Counter(y)

def list_to_dict(list_str):
    list_items = list_str.split(" ")
    result_dict = {}
    for item in list_items:
        # apple,4
        items = item.split(",")
        result_dict[items[0]] = int(items[1])

    return result_dict

# create a socket object
s1 = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
s2 = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
s3 = socket.socket(socket.AF_INET, socket.SOCK_STREAM)

# connection to hostname on the port.
s1.connect(('210.100.235.128', 3456))
s2.connect(('210.100.235.128', 3457))
s3.connect(('210.100.235.128', 3458))

data_str = "rfc hypertext transfer protocol http11 docs txtpdf draftietfhttpv diff1 diff2 errata obsoleted draft standard updated errata exist network working r fielding request comments uc irvine obsoletes j gettys category standards compaqw3c j mogul compaq h frystyk w3cmit masinter xerox p leach microsoft t bernerslee w3cmit june hypertext transfer protocol http11 status memo document specifies internet standards track protocol internet requests discussion please current edition internet protocol standards std standardization state distribution copyright notice copyright internet reserved abstract hypertext transfer protocol http collaborative hypermedia information generic stateless protocol name servers object management systems request methods error codes http data representation http worldwide web global information specification defines http11 rfc fielding standards page rfc http11 june contents introduction purpose7 requirements terminology overall notational conventions generic grammar augmented bnf protocol parameters http version uniform resource identifiers syntax url uri comparison datetime formats date delta seconds character sets missing charset content codings transfer codings chunked transfer coding media types canonicalization text defaults multipart types product tokens quality values language tags entity tags units http message message types message headers message body message length header request requestline method requesturi resource identified request request header statusline status code reason phrase header fielding standards page rfc http11 june entity entity header entity body type entity length connections persistent connections purpose overall proxy servers practical considerations message transmission requirements persistent connections flow monitoring connections error status messages continue status client behavior server prematurely closes method definitions safe idempotent methods safe methods idempotent methods options get head post put delete trace connect status code definitions informational continue switching protocols successful 2xx created nonauthoritative information content reset content partial content redirection multiple choices moved permanently found modified proxy unused fielding standards page rfc http11 june temporary redirect client error request unauthorized payment required forbidden found method allowed proxy authentication required request timeout gone length required precondition failed request entity too large requesturi too unsupported media type requested expectation failed server error internal server error implemented timeout http version supported access authentication content negotiation serverdriven negotiation agentdriven negotiation transparent negotiation caching http cache correctness warnings cachecontrol mechanisms explicit user agent warnings exceptions warnings clientcontrolled behavior expiration model serverspecified expiration heuristic expiration age calculations expiration calculations disambiguating expiration values disambiguating multiple responses validation model lastmodified dates fielding standards page rfc http11 june entity tag cache validators weak strong validators entity tags lastmodified dates89 nonvalidating conditionals cacheability constructing responses caches endtoend hopbyhop headers headers combining headers combining byte ranges caching negotiated responses shared nonshared caches errors incomplete cache behavior side effects get head invalidation updates deletions writethrough mandatory cache replacement history lists header definitions accept acceptcharset acceptencoding acceptlanguage acceptranges age allow authorization cachecontrol may stored caches modifications expiration mechanism cache revalidation reload controls notransform directive cache extensions contentencoding contentlanguage contentlength contentlocation contentmd5 contentrange contenttype date clockless origin server etag expires fielding standards page rfc http11 june host ifmatch ifmodifiedsince ifnonematch ifrange ifunmodifiedsince lastmodified location maxforwards pragma proxyauthenticate proxyauthorization byte ranges retrieval referer retryafter server te trailer transferencoding143 upgrade useragent vary via warning wwwauthenticate considerations personal information151 abuse server log information transfer sensitive information encoding sensitive information uris privacy issues connected accept headers based file path names dns spoofing location headers spoofing contentdisposition issues authentication credentials idle clients proxies caching denial proxies156 acknowledgments references authors addresses appendices internet media type internet media type tolerant applications differences http entities rfc entities fielding standards page rfc http11 june mimeversion canonical form date formats introduction contentencoding contenttransferencoding introduction transferencoding mhtml length limitations additional features contentdisposition compatibility previous versions http10 compatibility http10 persistent connections rfc index copyright statement introduction purpose hypertext transfer protocol http collaborative hypermedia information http worldwide web information initiative http http09 simple protocol raw data internet http10 rfc mimelike requestresponse semantics http10 persistent connections http10 protocol version true capabilities specification defines http11 stringent requirements http10 reliable implementation practical information systems search frontend update http uniform resource identifier uri url urn fielding standards page rfc http11 june messages internet multipurpose internet extensions mime http generic protocol user agents internet smtp nntp ftp gopher wais http basic hypermedia diverse applications requirements key words must must not required shall shall not should should not recommended may optional rfc must required level requirements must required should level requirements must level requirements should level requirements terminology specification uses http transport layer virtual circuit basic unit http http request message http response message fielding standards page rfc http11 june network data object uri resources representations eg multiple languages data formats size entityheader fields particular response status content negotiation appropriate representation error responses term variant establishes connections user agent editors spiders end user tools application program accepts connections service requests terms refers particular connection programs capabilities likewise origin server proxy gateway fielding standards page rfc http11 june origin server resource resides intermediary program possible translation must server requirements transparent proxy proxy authentication nontransparent proxy user agent group annotation services media type transformation protocol reduction nontransparent behavior http proxy requirements origin server intermediary program blind relay http http tunnel ceases local store response messages message storage retrieval cache stores cacheable responses network bandwidth consumption response message subsequent requests http additional constraints particular request fielding standards page rfc http11 june unnecessary delay origin server origin server explicit expiration time origin server heuristic expiration time expiration time explicit expiration origin server freshness lifetime expiration time freshness lifetime cache behaves transparent manner particular response origin server hopbyhop headers origin server protocol element eg entity tag lastmodified cache entry upstream messages flow fielding standards page rfc http11 june inbound response paths messages inbound origin server user agent overall http requestresponse protocol client sends request method uri protocol version mimelike modifiers client information possible body content server responds status line messages protocol version error code mimelike server information entity possible entitybody content http mime http user agent origin server connection v user agent ua origin server o request chain ua v o response chain situation occurs requestresponse chain intermediary proxy gateway uri absolute form uri tunnel acts relay point messages tunnels communication needs request chain ua v b v c v o response chain user agent origin server response message whole chain separate connections http communication options fielding standards page rfc http11 june multiple simultaneous communications example b internal cache requestresponse chain ua request chain ua v b c o response chain special requirements cache behavior http cache behavior cacheable responses wide variety web national hierarchies proxy caches transoceanic bandwidth systems multicast cache entries organizations cdrom http corporate intranets highbandwidth links pdas lowpower radio links intermittent connectivity http11 wide diversity protocol constructs web applications reliable indications http tcpip default port tcp http internet http such guarantees http11 response structures transport data units fielding standards page rfc http11 june http10 new connection requestresponse exchange http11 requestresponse exchanges notational conventions generic grammar augmented bnf backusnaur form bnf rfc implementors bnf name definition equal character white space continuation lines certain basic rules sp lws ht crlf digit alpha angle definitions whenever rule names quotation marks surround literal text unless rule1 rule2 elements alternatives eg yes rule1 rule2 elements elem foo token sequences elem foo elem full form m occurrences default zero 1element square brackets enclose optional elements foo fielding standards page rfc http11 june specific repetition nelement n occurrences 2digit number alphabetic characters full form m elements optional white space lws lws lws lws wherever null elements element element nonnull element must default rule text simple way lws white space lws adjacent words adjacent words lws must usascii ansi x341986 fielding standards page rfc http11 june octet 8bit sequence char usascii character octets upalpha usascii uppercase letter az loalpha usascii lowercase letter az alpha upalpha loalpha digit usascii ctl usascii control character del cr usascii cr carriage return lf usascii lf sp usascii sp ht usascii ht usascii doublequote mark http11 cr lf endofline marker protocol elements tolerant applications endofline marker media type crlf cr lf http11 header field values multiple lines continuation line horizontal tab white space sp may white space sp field value lws crlf sp ht text descriptive field contents message parser words text may iso rfc text octet ctls lws crlf text field continuation lws sp text hexadecimal numeric characters protocol elements hex b c d e b c d e f digit fielding standards page rfc http11 june http11 header field values consist lws special characters special characters must parameter value char ctls sp ht comments http header fields comment text comments field value definition fields parentheses ctext quotedpair comment text doublequote marks qdtext quotedpair text backslash character may comment constructs char protocol parameters http version http http message components communication behavior extensible field values minor number general message message semantics additional capabilities major number rfc fielding standards page rfc http11 june http httpversion httpversion http 1digit 1digit minor numbers must may http24 http213 http123 must must not response message httpversion http11 must applications should httpversion http11 must http10 httpversion rfc http http proxy gateway applications need protocol versions protocol version protocol capability must not actual version version request must request version interoperability problems http10 rfc must may must not proxygateways response must major version converting http header fields uniform resource identifiers uris www universal document identifiers universal resource identifiers uniform resource locators url names urn http uniform resource identifiers identifyvia name location characteristica resource fielding standards page rfc http11 june syntax uris http absolute form uri uris scheme name definitive information url uniform resource identifiers uri generic syntax semantics rfc rfcs rfc specification adopts urireference absoluteuri relativeuri port hostabs_path rel_path http priori limit uri servers must uri should uris getbased uris should requesturi too long status uri servers uri url http scheme network resources http section defines schemespecific syntax urls http_url http host port abs_path query tcp requesturi abs_path section ip urls should rfc url must requesturi resource section host name domain name may host name domain name must not fielding standards page rfc http11 june uri comparison uris should casesensitive octetbyoctet comparison uris urireference comparisons host names must comparisons scheme names must empty abs_path characters rfc hex hex uris httpabccom % 7esmithhomehtml httpabccom % 7esmithhomehtml datetime formats date http different formats datetime stamps sun nov gmt rfc rfc gmt rfc rfc sun nov ansi cs asctime format internet fixedlength subset rfc rfc common use rfc date format fourdigit year http11 date value must http10 must rfc httpdate header fields recipients date values date values smtp nntp fielding standards page rfc http11 june http datetime stamps must greenwich mean gmt http gmt utc coordinated universal gmt time zone must asctime format httpdate must not lws sp httpdate rfc1123date rfc850date asctimedate rfc1123date wkday sp sp sp gmt sp sp sp gmt asctimedate wkday sp sp sp sp sp day month year eg jun 2digit month 2digit daymonthyear eg 02jun82 sp sp month day eg jun 2digit 2digit 2digit mon tue wed thu fri sat sun jan feb mar apr may jun jul aug sep oct nov dec http datetime stamp format protocol stream clients user presentation request delta seconds http header fields time value integer number character sets http term character mime fielding standards page rfc http11 june term character unconditional conversion particular character various kinds simple singletable mappings usascii complex table iso2022s mime must particular use term character http mime http caseinsensitive tokens complete set iana character set http iana character set must applications should iana implementors ietf missing charset http10 contenttype charset parameter senders may iso88591 should http10 explicit charset parameter http11 must charset label user agents must fielding standards page rfc http11 june contenttype field recipients preference content codings content content media type frequently http11 acceptencoding contentencoding header fields internet assigned numbers iana value tokens registry contains file compression program gnu rfc lempelziv lz77 crc unix file compression program compress lempelzivwelch lzw program names future encodings historical practice previous implementations http should zlib format rfc deflate compression mechanism rfc fielding standards page rfc http11 june default identity accept encoding should not contentencoding value tokens should servers specifications new value should independent implementation transfer codings transfercoding safe transport original entity token parameter parameters attributevalue pairs attribute value http11 te header field section transferencoding header field section whenever must must must not message section transfercodings contenttransferencoding mime enable safe transport binary data 7bit transport service safe transport different focus http unsafe characteristic exact body length section encrypt data fielding standards page rfc http11 june internet assigned numbers iana value tokens registry contains identity section gzip section compress section value tokens should value tokens section should unimplemented must not http10 chunked transfer coding own size indicator optional entityheader fields full message chunkedbody crlf chunksize chunkextension crlf crlf crlf chunkextension chunkextname chunkextval crlf chunksize field hex digits empty line http trailer header field header fields fielding standards page rfc http11 june must not header fields athe request te header field bthe server origin server fields consist optional metadata origin server origin server trailer fields requirement prevents interoperability failure http11 http10 infinite buffer example process chunkedbody http11 must must ignore chunkextension extensions media types http internet media types contenttype accept header fields extensible data type negotiation type subtype parameter parameters may type subtype parameter attribute names parameter parameter name linear white space lws must not media type registry fielding standards page rfc http11 june http media type http should media type parameters typesubtype definition mediatype internet assigned number iana media type registration process rfc media types canonicalization text defaults internet media types canonical form http must appropriate canonical form text types canonical form media subtypes text type use crlf text line http text media cr lf entire entitybody http must crlf cr lf text media http cr lf multibyte character http cr lf text media cr lf must not crlf http header fields multipart boundaries must charset parameter media types explicit charset sender media subtypes default charset value iso88591 http data iso88591 must appropriate charset value compatibility problems multipart types mime multipart types encapsulations common syntax rfc fielding standards page rfc http11 june must boundary parameter media type message body protocol element must crlf rfc multipart message must http must not original multipart contains multipart message body wherein multipart boundary http multipart messagebody media type multipartbyteranges type appendix partial content http http user agent should mime user agent multipart type mime header fields multipart message http mime http user agent should mime user agent multipart type multipart subtype must multipartformdata type form data post request method rfc product tokens product software name product tokens significant part white space token productversion examples useragent cernlinemode215 server apache084 fielding standards page rfc http11 june product should must not nonessential information token character may should version identifier ie successive versions should productversion portion product value quality values http content negotiation section relative importance weight negotiable parameters real number quality value http11 must not decimal point user should quality relative degradation language tags language tag identifies natural language human beings human beings computer http uses language tags acceptlanguage content language http language tags rfc language tag primary language tag empty series primarytag subtag white space name space language tags iana example enus encockney icherokee xpiglatin fielding standards page rfc http11 june twoletter primarytag iso639 language abbreviation initial subtag iso3166 country code entity tags entity http11 uses entity tags etag ifmatch ifnonematch ifrange header fields cache validators entity tag weakness indicator entitytag weak opaquetag strong entity tag may octet equality weak entity tag w prefix may weak entity tag weak comparison entity tag must particular resource entity tag value may uris entity tag value uris units http11 response entity http11 uses range range section contentrange header fields various structural units bytesunit otherrangeunit range unit http11 http11 may fielding standards page rfc http11 june http11 http message message types http messages consist httpmessage request http11 request response section message format rfc message consist startline zero header fields empty line ie crlf header fields genericmessage startline crlf crlf requestline statusline robustness servers should requestline protocol stream crlf crlf certain buggy http10 client implementations generate crlfs post bnf http11 must not crlf message headers http header fields generalheader section requestheader section responseheader section entityheader section generic format rfc header field field value field names field value may lws sp header multiple lines extra line sp ht applications common form http fielding standards page rfc http11 june common forms messageheader fieldname fieldvalue lws octets text token separators lws white space lws may field value lws may sp field value header fields field names good practice generalheader fields header fields entityheader fields multiple messageheader fields may entire fieldvalue header field list ie values must multiple header fields fieldname fieldvalue pair subsequent fieldvalue header fields field value must not field values message body http transferencoding header field section messagebody entitybody transferencoding transferencoding must transferencoding fielding standards page rfc http11 june may requestresponse chain places restrictions certain transfercodings message differ contentlength transferencoding header field requests messageheaders must not request method section should request method should response messages request method status code section head request method must not header fields must not may zero length message length 1any response message must not head empty line header fields regardless entityheader fields transferencoding header field section contentlength header field section decimal value octets contentlength header field must not different ie transferencoding fielding standards page rfc http11 june header field transferencoding header field contentlength header field must message uses media type multipartbyteranges media type defines media type ust not range header ultiple byte range specifiers client implies multipartbyteranges responses range header must closing request body http10 http11 must contentlength http11 request contains contentlength should bad request contentlength http11 must message length messages must not contentlength header field contentlength must contentlength field value must octets http11 user agents must invalid length header header fields general applicability response messages header fields fielding standards page rfc http11 june cachecontrol date pragma trailer transferencoding upgrade via warning generalheader field names protocol version experimental header fields header fields generalheader fields unrecognized header fields entityheader fields request request message protocol version request requestline crlf crlf requestline requestline requesturi protocol version crlf sp cr lf crlf requestline method sp requesturi sp httpversion crlf fielding standards page rfc http11 june method method requesturi method options get head post put delete trace connect allow header field section return code origin server should status code method allowed origin server implemented origin server get head must generalpurpose servers optional above methods must requesturi requesturi uniform resource identifier requesturi absoluteuri abs_path authority requesturi particular resource options http11 absoluteuri form required valid cache may fielding standards page rfc http11 june request loops must server names local variations ip requestline get http11 http http11 must http11 authority form connect method section common form requesturi origin server uri must requesturi network location uri must host header field origin server tcp host wwww3org get http11 host request absolute path uri must server root requesturi requesturi hex hex origin server must requesturi servers should requesturis appropriate status code transparent proxy must not abs_path part requesturi inbound server null abs_path rewrite rule prevents origin server uri implementors prehttp11 proxies requesturi fielding standards page rfc http11 june resource identified request exact resource internet requesturi host header field origin server may host header field value http11 host http11 origin server differentiate resources virtual hosts vanity host must http11 requesturi requesturi host header field value must requesturi host header field host field value valid host must request error message recipients http10 host header field may heuristics eg examination uri particular host exact resource request header requestheader fields request modifiers language method accept acceptcharset acceptencoding acceptlanguage authorization host ifmatch fielding standards page rfc http11 june ifmodifiedsince ifnonematch ifrange ifunmodifiedsince maxforwards proxyauthorization referer te useragent requestheader field names protocol version experimental header fields may header fields requestheader fields unrecognized header fields entityheader fields request message server responds http response message statusline crlf crlf statusline response message statusline protocol version numeric status code textual phrase sp cr lf crlf statusline httpversion sp statuscode sp reasonphrase crlf status code reason phrase statuscode 3digit integer result code reasonphrase textual description statuscode statuscode reasonphrase reason phrase fielding standards page rfc http11 june statuscode categorization role informational request 2xx success redirection client error request contains bad syntax server error valid request individual values numeric status codes http11 reasonphrases reason phrases may local equivalents statuscode continue switching protocols created nonauthoritative information content reset content partial content multiple choices moved permanently found modified proxy temporary redirect request unauthorized payment required forbidden found method allowed fielding standards page rfc http11 june proxy authentication required request timeout gone length required precondition failed request entity too large requesturi too large unsupported media type requested expectation failed internal server error implemented timeout http version extensioncode 3digit reasonphrase text cr lf http status codes http status codes must status code x00 status code must not status code status code cases user agents should readable information unusual status header responseheader fields status header fields requesturi acceptranges age etag location proxyauthenticate fielding standards page rfc http11 june retryafter server vary wwwauthenticate responseheader field names protocol version experimental header fields may header fields responseheader fields unrecognized header fields entityheader fields entity request response messages may request method response status code entityheader fields entity header entityheader optional required allow contentencoding contentlanguage contentlength contentlocation contentmd5 contentrange contenttype expires lastmodified extensionheader messageheader extensionheader mechanism additional entityheader fields unrecognized should must transparent proxies fielding standards page rfc http11 june entity body http entityheader fields octet transferencoding type data type header fields contenttype content encoding contentencoding contenttype contenttype media type contentencoding additional content http11 should contenttype header field media type media type contenttype may media type content andor name extensions uri media type should type applicationoctetstream entity length fielding standards page rfc http11 june connections persistent connections purpose persistent connections tcp url http internet inline images short amount analysis performance problems implementation experience http11 rfc alternatives ttcp persistent http tcp cpu hosts clients servers proxies gateways tcp protocol control http pipelining multiple requests tcp network tcp tcp sufficient time congestion state latency subsequent requests tcps connection opening handshake http tcp clients future versions http server retry http should persistent connections fielding standards page rfc http11 june overall significant difference http11 http persistent connections default behavior http should persistent connection error responses persistent tcp header field section must not negotiation http11 may http11 persistent connection should http11 may should server sends clients should not persistent connection http http10 must message length ie fielding standards page rfc http11 june pipelining persistent connections may requests ie multiple requests must clients persistent connections connection establishment should must not clients must server closes corresponding responses clients should not pipeline requests nonidempotent methods nonidempotent sequences otherwise premature termination transport connection indeterminate results should response status previous request proxy servers header field proxy server must persistent connections origin servers proxy servers persistent connection applies proxy server must not http11 persistent connection http10 rfc keepalive http10 practical considerations servers timeout value inactive connection proxy connections places fielding standards page rfc http11 june server wishes should transport connection clients should unnecessary resource client server may transport connection new request clients servers must client should transport connection user interaction request sequence nonidempotent must not user agents may human operator confirmation useragent software semantic understanding may user confirmation automatic retry should not servers should servers should not client failure clients persistent connections should simultaneous connections singleuser client should not should 2n connections active users http message transmission requirements persistent connections flow http11 should persistent connections tcps flow control mechanisms temporary overloads exacerbate network congestion fielding standards page rfc http11 june monitoring connections error status messages http11 should network connection error status error status should zero length chunk empty trailer may contentlength must continue status continue request message request body origin server request headers client sends requirements http11 continue request body must field section 100continue expectation must not requestheader field section 100continue expectation request body ambiguous situations expectation failed continue client sends header field origin server continue should not indefinite period request body requirements http11 origin servers upon 100continue expectation origin server must continue input stream final status code origin server must not request body continue final status may transport connection may fielding standards page rfc http11 june must not final status code origin server should not continue request message 100continue expectation must not continue http10 rfc may continue http11 put post requestheader field client processing delays continue status applies http11 http version value origin server may continue request body corresponding request origin server continue must final status code request body origin server requestheader field 100continue expectation request body server responds final status code entire request body transport connection should not transport connection entire request client closes otherwise response message denialofservice attacks client implementations requirements http11 header field 100continue expectation nexthop server complies http11 http must fielding standards page rfc http11 june nexthop server http10 must not must expectation failed proxies should http nexthop servers must not continue request message http10 requestheader field 100continue expectation requirement overrides general rule 1xx responses client behavior server prematurely closes http11 client sends request body requestheader field 100continue expectation http11 origin server should may binary exponential backoff reliable response initiate new connection transmit initialize roundtrip time server eg constant value trip time compute t r wait error response error response seconds transmit retry process fielding standards page rfc http11 june error status should not should request message method definitions common methods http11 additional methods host requestheader field section must http11 safe idempotent methods safe methods implementors internet unexpected significance get head should not user agents post put delete special way unsafe action generate sideeffects get dynamic resources idempotent methods methods expiration issues get head put delete options trace should not fielding standards page rfc http11 june entire sequence concurrent operations options options communication options requestresponse chain requesturi options andor requirements resource action resource retrieval responses options contentlength transferencoding media type must contenttype http options may request body requesturi options servers communication options http11 lack thereof requesturi options request applies should header fields resource eg allow response body should communication options fielding standards page rfc http11 june future extensions http content may appropriate response format response body must contentlength maxforwards requestheader field may specific proxy request chain options must maxforwards maxforwards must not should own communication options maxforwards must maxforwards must not maxforwards get get requesturi requesturi source text get get request message ifmodifiedsince ifunmodifiedsince ifmatch ifnonematch ifrange header field get method requests conditional header fields get unnecessary network multiple requests get get request message range header field get get network usage get http security considerations fielding standards page rfc http11 june head head get must not http head should get hypertext links validity accessibility recent modification head may may new field values entity differs current entity contentlength contentmd5 etag lastmodified must cache entry post post origin server new subordinate requesturi requestline post uniform method annotation posting bulletin board newsgroup similar group providing extending append operation actual function post requesturi uri news article post uri content appropriate response status fielding standards page rfc http11 june origin server should created new resource location responses cachecontrol expires header fields user agent cacheable resource post must message transmission requirements security considerations put put method requests requesturi requesturi should origin server requesturi uri new resource origin server uri new resource origin server must user agent created content response codes should successful completion requesturi error response should must not content contentrange must implemented such cases requesturi should responses fundamental difference post put different meaning requesturi uri post request identifies separate entity accepts annotations uri put request identifies user agent uri must not server desires uri fielding standards page rfc http11 june must moved permanently user agent may own decision may uris uri uri put uri uris origin server http11 put method affects origin server put must message transmission requirements unless particular entityheader put should put delete delete method requests origin server delete requesturi may origin server status code origin server should not successful response should content requesturi should responses trace trace remote applicationlayer loop request message final recipient should ok response final recipient fielding standards page rfc http11 june origin server maxforwards trace must not trace request chain via header field section particular interest request chain maxforwards header field request chain infinite loop should request message contenttype responses must not connect specification reserves method name connect tunnel eg ssl status code definitions statuscode informational status code provisional response statusline optional headers empty line status code http10 1xx status codes servers must not 1xx response http10 experimental conditions must 1xx status responses regular response continue status message unexpected 1xx status responses may user agent proxies must 1xx responses 1xx response fielding standards page rfc http11 june 100continue field continue continue should interim response initial part should must final response status code switching protocols upgrade message header field section application protocol switch protocols upgrade header field empty line should http realtime synchronous such features successful 2xx status code clients request get head entityheader fields post fielding standards page rfc http11 june trace request message end server created new resource uris uri location header field should user agent entity format media type contenttype header field must status code should may etag response header field current value entity tag status code asynchronous operation user agents connection server persist should current status status monitor nonauthoritative information definitive set origin server thirdparty copy may original version annotation information origin server response code fielding standards page rfc http11 june content may should user agent should not document view user agents active document view should user agents active view must not empty line header fields reset content user agent should document view user input input action must not partial content get must range header field section may ifrange header field section request conditional must header fields either contentrange header field section contenttype contentrange contentlength header field must actual number octets date etag contentlocation fielding standards page rfc http11 june expires cachecontrol vary previous response ifrange strong cache validator should not ifrange weak validator must not prevents inconsistencies otherwise must ok response must not etag lastmodified contentrange must not partial redirection status code action needs user agent may user agent get head should detect infinite redirection loops such loops generate network traffic previous versions content multiple choices resource corresponds own specific location negotiation information section user agent unless head should resource characteristics user agent entity format media type content type header field depending fielding standards page rfc http11 june user agent selection appropriate choice may such automatic selection should uri location field user agents may location field value moved permanently uri future references should uris clients link editing capabilities relink references requesturi uri should location unless request method head should short hypertext note uris status code get head user agent must not post status code http10 user agents get found resource resides uri should requesturi future requests cachecontrol expires uri should location unless request method head should short hypertext note uris fielding standards page rfc http11 june status code get head user agent must not rfc rfc user agent implementations get location fieldvalue regardless original request method status codes uri should get postactivated user agent uri substitute reference must not uri should location unless request method head should short hypertext note uris prehttp11 user agents such clients status code user agents modified get should status code must not empty line header fields must header fields date fielding standards page rfc http11 june clockless origin server obeys date rfc etag contentlocation expires cachecontrol vary previous response get strong cache validator should not otherwise get weak validator must not must cache uses cache entry must new field values proxy must location location uri must origin servers rfc origin servers significant security consequences unused status code previous version fielding standards page rfc http11 june temporary redirect resource resides uri may should requesturi future requests cachecontrol expires uri should location unless request method head should short hypertext note uris prehttp11 user agents should original request uri status code get head user agent must not client error 4xx class status code head should error situation status codes request method user should server implementation tcp should client acknowledges receipt server closes input connection tcp reset packet input buffers http request should not fielding standards page rfc http11 june unauthorized user authentication must wwwauthenticate header field section may authorization header field section authorization response contains user agent should relevant diagnostic information http access authentication http authentication digest access authentication payment required future use forbidden authorization should not request method head server wishes should status code found found requesturi gone status code should configurable mechanism status code method allowed requestline requesturi must allow valid methods fielding standards page rfc http11 june response entities content characteristics unless head should available entity characteristics user agent entity format media type contenttype header field depending user agent selection may such automatic selection http11 user user agent should proxy authentication required unauthorized must proxyauthenticate header field section may proxyauthorization header field section http access authentication http authentication digest access authentication request timeout may response body should fielding standards page rfc http11 june response entity user agent conflicts put put thirdparty request response entity contenttype gone clients link editing capabilities should delete references requesturi user approval status code found should server owners desire remote links promotional services servers site unavailable resources server owner length required server refuses content length may contentlength header field request message precondition failed requestheader fields current resource metainformation header field data fielding standards page rfc http11 june request entity too large may should retry header field may requesturi too requesturi post get long query uri black hole redirection eg uri security holes requesturi unsupported media type requested should status code range requestheader field section rangespecifier values field overlap current extent ifrange requestheader field byterangespec values current length status code byterange request should contentrange entityheader field current length must not multipartbyteranges content fielding standards page rfc http11 june expectation failed requestheader field unambiguous evidence nexthop server server error response status codes beginning head should error situation user should response codes request method internal server error unexpected condition implemented appropriate response request method upstream server temporary condition may retryafter retryafter should status code fielding standards page rfc http11 june timeout timely response upstream server uri http ftp ldap auxiliary server eg dns dns lookups time http version supported http request message major version error message should access authentication http optional challengeresponse authentication authentication information general framework access authentication digest authentication http authentication digest access authentication specification adopts content negotiation http contains information human user available entity user agents entity types http content negotiation multiple representations format negotiation alternate representations media type different capabilities different languages fielding standards page rfc http11 june may error responses content negotiation http agentdriven negotiation negotiation occurs cache uses agentdriven negotiation origin server serverdriven negotiation subsequent requests serverdriven negotiation selection available representations eg language particular header fields request message network address serverdriven available representations user agent server desires roundtrip delay subsequent request user agent may request header fields accept acceptlanguage acceptencoding serverdriven complete knowledge user agent response eg user agent describe multiple representations potential violation users privacy origin server fielding standards page rfc http11 june public caches ability multiple users requests http11 requestheader fields serverdriven negotiation user agent user preferences accept accept charset acceptencoding accept language useragent origin server may requestheader fields header fields vary header field server uses vary header field vary header field agentdriven negotiation agentdriven negotiation selection user agent initial response origin server selection available representations header fields initial response uri selection user agent hypertext menu agentdriven type language origin server user agents server load network usage agentdriven negotiation suffers alternate representation automatic selection http11 fielding standards page rfc http11 june http11 multiple choices status codes agentdriven negotiation transparent negotiation transparent agentdriven negotiation available representations origin server transparent negotiation work request delay such mechanism http11 caching http http information systems response caches http11 http headers response codes etc caching http11 full responses network roundtrips expiration mechanism reduces network bandwidth requirements requirements performance availability http11 origin servers caches fielding standards page rfc http11 june nontransparent operation confuse nonexpert certain server applications explicit protocollevel request origin server explicit warning end user http11 important elements protocol full semantic transparency protocol origin server user agent control nontransparent operation protocol attach warnings semantic transparency basic principle potential relaxation semantic transparency server cache client implementor design decisions semantic transparency complete analysis shows significant benefits cache correctness correct cache must origin server origin server section fielding standards page rfc http11 june default case restrictive freshness requirement client origin server origin server freshness requirement origin server restrictive freshness requirement origin server may warning nostore cachedirective nocache cacherequestdirective modified proxy redirect error 4xx 5xx response message origin server should must communication failure entire response modified should warning warning should not might lead user agent stale response warning may warning indication warnings whenever cache returns must warning warning warnings may error status code true failures warnings digit warncodes warning must must not cache entry successful revalidation fielding standards page rfc http11 june warnings revalidation status must revalidation 1xx warncodes may must not warnings entity body lossy compression entity bodies must not successful revalidation http10 warnings warnings http10 extra warningdate field http11 warning warnings warning text may appropriate natural language accept optional multiple may multiple warnings english basque multiple warnings http specify strict priority rules cachecontrol mechanisms basic cache mechanisms http11 implicit directives explicit directives http cachecontrol cachecontrol general rule apparent conflict restrictive interpretation semantic transparency fielding standards page rfc http11 june cases cachecontrol directives semantic transparency cachecontrol directives explicit user agent warnings user agents user agent stale ones user agent cache control maxstale3600 user agent should not nontransparent behavior may explicit action should user whenever transparency requirements user agent indication need indication need dialog box user agent should consume excess resources exceptions warnings may return stale responses origin server whenever cache returns must warning client software fielding standards page rfc http11 june user agent fresh response should not policy reasons clientcontrolled behavior origin server lesser extent intermediate caches expiration information caches decision clients cachecontrol clients request may maximum age zero forces may minimum time options increase constraints caches approximation semantic transparency may stale responses maximum amount origin servers semantic transparency high availability poor connectivity expiration model serverspecified expiration http origin server primary mechanism origin server explicit expiration may subsequent requests expiration times significant way expiration time preserves semantic servers expiration times fielding standards page rfc http11 june expiration mechanism applies firsthand responses origin server wishes transparent cache may explicit expiration time should subsequent requests restrictive way force revalidation origin server wishes http11 should revalidate cachecontrol directive servers explicit expiration times expires maxage directive cachecontrol expiration time user agent such mechanisms need expiration status new request history mechanisms heuristic expiration origin servers explicit expiration times http heuristic expiration times header values lastmodified plausible expiration time http11 specific algorithms worstcase constraints heuristic expiration compromise semantic transparency origin servers expiration times age calculations cache needs age exceeds freshness lifetime cache entry current value hosts http origin servers should ntp similar protocol accurate time fielding standards page rfc http11 june http11 origin servers date term date_value date http11 age response message age field value origin server age origin server network paths term age_value age arithmetic operations responses age independent ways minus date_value local clock origin servers clock response path http11 independent ways corrected_received_age maxnow date_value age_value http11 reliable conservative result significant interval server generates outbound cache low ages age age values generation age must fielding standards page rfc http11 june algorithm results conservative behavior corrected_initial_age corrected_received_age local clock summary age calculation algorithm age origin servers date local time local time current local time apparent_age max0 response_time date_value corrected_received_age maxapparent_age age_value response_delay response_time request_time corrected_initial_age corrected_received_age + response_delay corrected_initial_age + resident_time cache entry cache entry origin server cache entry must age header field cache entrys age header field response implies age header field fielding standards page rfc http11 june request path http11 http age header field expiration calculations freshness lifetime freshness lifetime arithmetic operations term expires_value expires term max_age_value maxage directive cachecontrol maxage directive expires freshness_lifetime max_age_value otherwise expires freshness_lifetime expires_value date_value clock skew origin server expires cachecontrol cachecontrol may freshness lifetime must warning such warning lastmodified expiration value should typical setting response_is_fresh freshness_lifetime current_age fielding standards page rfc http11 june disambiguating expiration values expiration values fresh values nonfirsthand response own cache date cache entry date may may cachecontrol maxage0 directive origin server fresh responses different validators must date fresh cache entry disambiguating multiple responses multiple paths responses flow responses flow different set entity tag expiration value expiration time date client tries cache entry date should cachecontrol intermediate caches origin server cachecontrol intermediate caches new copy fielding standards page rfc http11 june date may may prudent request new response servers must not expiration times overlap validation model stale entry clients request intermediate cache fresh response cache entry full response extra round trip http11 protocol supports conditional methods key protocol conditional methods cache validators origin server full response cache entry client user agent proxy cache conditional request cache entry current validator special status code modified otherwise full response full response validator matches extra round trip http11 conditional request get negative senses validator matches fielding standards page rfc http11 june cachecontrol directive conditional retrieval lastmodified dates lastmodified entityheader field value simple terms cache entry lastmodified entity tag cache validators etag responseheader field value entity tag opaque cache validator reliable validation store modification dates onesecond resolution http date values origin server wishes modification dates entity tags entity tags weak strong validators origin servers different entities headers changes strong validator significant changes insignificant aspects a validator resource changes weak validator entity strong validators entity tag strong validator changes whenever weak value changes whenever alternatively strong validator specific entity weak validator equivalent entities strong validator stable storage fielding standards page rfc http11 june entitys modification time weak validator support weak validators weak validators equivalent objects hit counter client generates header field server compares strong weak exact equality get strong validator inconsistent entity clients may simple nonsubrange get strong validators clients must not weak validators http11 protocol defines validator comparison functions comparison context weak validators strong comparison function must must not weak comparison function must may entity tag entity tags lastmodified origin server actual current validator fielding standards page rfc http11 june origin server modifiedsince ifunmodifiedsince cache entry cache entry date origin server original response lastmodified date intermediate cache cache entry cache entry date origin server original response lastmodified date method relies different responses origin server lastmodified date lastmodified limit guards date modified different clocks different times may client wishes subrange retrieval lastmodified opaque validator may lastmodified origin server conditional request get must strong comparison function http11 range retrievals http10 fielding standards page rfc http11 june entity tags lastmodified dates origin servers various validator types http11 origin servers should entity tag validator may weak entity tag strong entity tag performance considerations support weak entity tags strong entity tag should lastmodified semantic transparency ifmodifiedsince serious problems http11 origin server strong entity tag lastmodified strong entity tag must entity value changes weak entity tag should entity changes significant way origin server specific strong entity tag different entities specific weak entity tag value different entities cache long periods regardless expiration times http11 entity tag origin server must entity tag cacheconditional request match ifnonematch lastmodified should nonsubrange cacheconditional ifmodifiedsince fielding standards page rfc http11 june lastmodified http10 origin server may subrange cacheconditional ifunmodifiedsince user agent should entity tag lastmodified origin server should cacheconditional requests http10 http11 http11 origin server conditional request lastmodified date eg ifmodifiedsince ifunmodifiedsince header field entity tags eg ifmatch ifnonematch ifrange header field must not response status modified conditional header http11 conditional request lastmodified entity tags cache validators must not conditional header fields general principle http11 http11 conservative assumptions http10 ignore entity tags support transparent http11 lastmodified rare cases lastmodified http10 serious problem http11 origin servers nonvalidating conditionals entity tags service author appropriate cache validation mechanism validator comparison function lastmodified http10 cache entry fielding standards page rfc http11 june cacheability unless cachecontrol section may successful response cache entry may may successful validation cache validator explicit expiration time certain caches may network connectivity date current time http10 warning absolute semantic transparency service author privacy considerations certain cachecontrol directives resource entities portions thereof previous request authorization status code may request subject expiration mechanism directive prohibits contentrange must not partial content status code eg status codes must not subsequent request cachecontrol directives expires header section maxage smaxage revalidate proxyrevalidate private cachecontrol directive section fielding standards page rfc http11 june constructing responses caches http store information future requests appropriate parts cache entry previous response cache entry endtoend hopbyhop headers http endtoend endtoend must cache entry must cache entry hopbyhop transportlevel connection http11 hopbyhop headers keepalive proxyauthenticate proxyauthorization te trailers transferencoding upgrade http11 endtoend headers hopbyhop headers must http11 headers http11 digest authentication certain endtoend headers transparent proxy should not endtoend header fielding standards page rfc http11 june transparent proxy must not must not contentlocation contentmd5 etag lastmodified transparent proxy must not expires may expires must date must not notransform cachecontrol directive contentencoding contentrange contenttype nontransparent proxy may must warning transformation warning unnecessary modification endtoend headers authentication failures http authentication mechanisms may header fields contentlength transparent proxy must entitylength section may transferlength section fielding standards page rfc http11 june combining headers modified partial content status code modified cache uses cache entry status code partial content etag lastmodified may cache entry new contents endtoend headers cache entry warning warncode 1xx must cache entry warning warncode 2xx must cache entry endtoend headers must corresponding headers cache entry unless cache entry must endtoend headers cache entry corresponding headers warning header field response matches cache entry such old headers must endtoend headers response overrides corresponding endtoend headers cache entry warning warncode 1xx origin server modified partial content previous response origin server modified partial content fielding standards page rfc http11 june combining byte ranges such transfers response transfers may new subrange cache entry cache validators strong comparison must recent partial response date must partial information caching negotiated responses serverdriven content negotiation section vary header field response alters subsequent requests vary should vary header field requestheader fields cacheable response subject header fields vary field value subsequent request requesturi cache entries vary header field must not cache entry new request new request original request fielding standards page rfc http11 june white space lws bnf messageheader fields field name message headers vary header fieldvalue origin server request header fields request header fields new request must not new request origin server server responds modified entity tag contentlocation entity tag should entity tags ifnonematch header field cache entries entities matches etag header field modified new response matches new response should header fields must cache entries contains only partial content should not ifnonematch header field successful response contentlocation field matches cache entry request uri entitytag differs date should not future requests should shared nonshared caches accessibility should appropriate security mechanisms fielding standards page rfc http11 june specification place certain constraints errors incomplete cache behavior incomplete response contentlength may must partial may full response must not partial response partial content status code must not partial response status code 5xx response may may mustrevalidate cachecontrol directive side effects get head unless origin server get head should not erroneous behavior may such side caches origin servers explicit restrictions gets heads urls rel_path part significant side must not uris explicit expiration time http10 uris should not invalidation updates deletions certain methods cache entries origin server new request fielding standards page rfc http11 june http cache entries origin server cache entry erroneous behavior phrase invalidate http must requesturi location contentlocation put delete post service attacks uri location contentlocation must host part requesturi should requesturi writethrough mandatory origin servers resources must get head must not inbound server corresponding response inbound server proxy cache continue inbound server final reply http11 server cache fielding standards page rfc http11 june cache replacement should new response current request may cache storage may future requests old response new response cache storage new response date header value history lists user history mechanisms history particular history should not transparent view current state history mechanism expiration time history mechanisms history mechanism should history documents history mechanism history list mechanisms stale resources force service authors http service authors error messages warning messages back interface considerations service authors urls fielding standards page rfc http11 june header definitions section defines http11 header fields entityheader fields accept accept requestheader field certain media accept accept accept mediarange acceptparams type subtype q qvalue acceptextension asterisk character group media types media types may media type may q parameter relative quality q parameter quality user agent relative degree qvalue scale default value q parameter name separate media type accept media type parameter media range q parameters iana media type registry rare usage media type accept media types fielding standards page rfc http11 june accept audio q02 audiobasic should % markdown accept header field client accepts media types accept header field accept field value should acceptable response accept textplain q05 texthtml textxdvi q08 textxc verbally media types textxdvi entity media specific media specific media types media range applies specific reference accept text texthtml texthtmllevel1 media type quality factor media range accept textq03 texthtmlq07 texthtmllevel1 texthtmllevel2q04 q05 fielding standards page rfc http11 june a user agent certain media user agent acceptcharset acceptcharset requestheader field purpose character acceptcharset acceptcharset charset q qvalue character may quality value default value acceptcharset iso88595 unicode11q08 special value acceptcharset iso88591 acceptcharset acceptcharset quality value iso88591 quality value acceptcharset acceptcharset acceptcharset should error response acceptable status code unacceptable response acceptencoding acceptencoding requestheader field accept contentcodings section acceptencoding acceptencoding fielding standards page rfc http11 june codings q qvalue examples acceptencoding compress gzip acceptencoding acceptencoding acceptencoding compressq05 gzipq10 acceptencoding gzipq10 identity q05 q0 server tests acceptencoding acceptencoding special symbol acceptencoding field matches multiple contentcodings nonzero qvalue acceptencoding acceptencoding acceptencoding acceptencoding should error response acceptable status code acceptencoding may available contentcodings should additional information acceptencoding http10 clients ie fielding standards page rfc http11 june display messages particular useragent http10 obey qvalues acceptlanguage acceptlanguage requestheader field accept natural languages language acceptlanguage acceptlanguage languagerange q qvalue 18alpha 18alpha may quality value users preference quality value defaults acceptlanguage da engbq08 enq07 english english a languagerange matches tag character special range acceptlanguage acceptlanguage language tags prefix rule prefix tags language quality factor acceptlanguage quality value longest language field matches language quality factor acceptlanguage fielding standards page rfc http11 june should acceptlanguage quality factor privacy expectations acceptlanguage complete linguistic preferences individual user client applications acceptlanguage header field must not linguistic preference remind implementors appropriate guidance example users english english user agent acceptranges acceptranges responseheader field range requests acceptranges acceptranges acceptableranges 1rangeunit origin byterange requests may acceptranges clients may generate byterange range units servers range request may acceptranges range request fielding standards page rfc http11 june age age responseheader field conveys origin server freshness lifetime age age age agevalue deltaseconds age nonnegative decimal integers age calculations must age http11 must age header field own cache caches should arithmetic type allow allow entityheader field requesturi valid methods allow header field must method allowed allow allow method example allow get head put allow header field value should actual set origin server allow header field may put should allow fielding standards page rfc http11 june must not allow header field user agent origin server authorization user agent authorization requestheader field authorization field value authentication information user agent authorization authorization http access authentication http authentication digest access authentication should authentication scheme challenge value authorization must not corresponding response specific exceptions smaxage cachecontrol may subsequent request maximum age proxy cache must new request origin server new request must mustrevalidate cachecontrol may subsequent request must origin server new request origin server new request public cachecontrol directive may subsequent request fielding standards page rfc http11 june cachecontrol cachecontrol generalheader field specify directives must requestresponse chain directives specify behavior cache http10 cachecontrol pragma cache must application regardless requestresponse chain specific cache cachecontrol cachecontrol cachedirective cacherequestdirective maxage deltaseconds maxstale deltaseconds minfresh deltaseconds private 1fieldname section nocache 1fieldname section maxage deltaseconds smaxage deltaseconds fielding standards page rfc http11 june 1fieldname parameter directive applies entire request 1fieldname parameter mechanism supports extensibility implementations future versions http header fields http11 cachecontrol directives restrictions origin server restrictions origin server user agent modifications basic expiration mechanism origin server user agent controls cache revalidation user agent extensions request method request header fields response status cacheable section cachecontrol response directives origin server default cacheability indicates may authorization additional details indicates response message must not origin server fielding standards page rfc http11 june may message content nocache directive must not subsequent request successful revalidation origin server origin server stale responses client requests nocache directive may subsequent request must not subsequent request successful revalidation origin server certain header fields http10 may stored caches nostore directive inadvertent release sensitive information backup tapes nostore directive applies entire message may must not must not directive applies must not must not nonvolatile storage must besteffort attempt volatile storage response users system eg save history may such responses normal operation fielding standards page rfc http11 june certain users service authors accidental releases cache data structures not sufficient mechanism particular malicious communications networks modifications expiration mechanism expiration time may expires alternatively may maxage directive maxage cachecontrol directive current age new request maxage directive response implies cacheable ie restrictive cache directive expires maxage directive overrides expires expires expiration time http11 http10 http10 calculate ages expiration times http10 cache implementations expires date cachecontrol response directive nocache http11 cachecontrol header field should http10 origin server http cache control private directive origin server expires date fielding standards page rfc http11 june smaxage directive private cache maximum age directive overrides maximum age maxage directive expires smaxage directive proxyrevalidate directive subsequent request origin server maxage directive private cache cachecontrol directives origin server cachecontrol directive http11compliant may maxage directive overrides expires prehttp11compliant caches maxage directive user agent basic expiration may indicates unless stale directive stale response indicates freshness lifetime current age indicates expiration time expiration time stale response cache returns stale response expiration time must warning stale response warning fielding standards page rfc http11 june may stale responses mustlevel cache validation eg cachecontrol directive new request cache revalidation reload controls user agent cache entry origin server origin server cache entry origin server endtoend origin server expiration time endtoend cache entry endtoend unspecified endtoend revalidation specific endtoend cache control request directives endtoend nocache cachecontrol directive http10 pragma nocache field must not nocache directive must not specific endtoend revalidation maxage0 cachecontrol directive origin server own entry initial request current validator unspecified endtoend revalidation maxage0 cachecontrol directive origin server own entry initial request fielding standards page rfc http11 june cache entry current validator intermediate cache own cache entry own validator may own request semantic transparency intermediate cache modified ok response new entity cache validator intermediate cache clients request strong comparison function clients validator origin servers intermediate cache modified otherwise new entity ok response nocache directive should not minfresh maxstale poor network origin server should timeout may may expiration time client request may stale directive similar effect origin server cache entry subsequent use must not fielding standards page rfc http11 june subsequent request ie must endtoend revalidation origin servers expires mustrevalidate directive certain protocol http11 must mustrevalidate directive origin server must timeout servers should mustrevalidate directive incorrect operation recipients must not must not user agents severe connectivity constraints may must must should explicit user confirmation proxyrevalidate directive revalidate directive user agent caches users cache public cache control directive notransform directive implementors intermediate caches proxies media type certain entity bodies transparent proxy cache space slow link serious operational problems entity bodies example applications fielding standards page rfc http11 june scientific data analysis entity body original entitybody notransform directive intermediate cache must not must not cache extensions cachecontrol header field cacheextension tokens informational cache behavior may behavioral cache directives standard directive new directive standard directive new directive standard directive cachecontrol directives base protocol http cachecontrol directives httpversion certain extensions new response directive private directive new directive origin server uci cachecontrol private communityuci header field community cacheextension private directive fielding standards page rfc http11 june unrecognized must http11 standard directives responses default cache behavior generalheader field particular connection must not http11 must header field header fields header field corresponding additional header fields additional header connection option message must not endtoend headers cachecontrol http11 close connection option response header fields should not persistent section current requestresponse http11 persistent connections must close connection option http10 lowerversion message must header fields such header fields prehttp11 proxies fielding standards page rfc http11 june contentencoding contentencoding entityheader field additional content contenttype header field contentencoding media type contentencoding contentencoding content contentencoding requesturi typically analogous usage nontransparent proxy may notransform cachecontrol directive must contentencoding entityheader section nonidentity contentcodings request message origin server should status code unsupported media type multiple encodings must additional may entityheader fields contentlanguage contentlanguage entityheader field contentlanguage contentlanguage fielding standards page rfc http11 june language primary purpose contentlanguage body content danishliterate appropriate field contentlanguage contentlanguage language audiences natural language multiple may multiple audiences waitangi maori english contentlanguage multiple languages multiple linguistic audiences beginners language primer lesson englishliterate contentlanguage contentlanguage may media type textual documents contentlength contentlength entityheader field decimal number octets head get contentlength contentlength contentlength applications should fielding standards page rfc http11 june contentlength valid value contentlength corresponding definition mime optional field messageexternalbody contenttype http should messages length contentlocation contentlocation entityheader field may resource location uri should contentlocation response entity multiple entities separate locations should contentlocation particular variant contentlocation contentlocation absoluteuri relativeuri contentlocation uri contentlocation uri particular entity may contentlocation uri uri contentlocation uri contentlocation uri content location multiple entities contentlocation uri uri requesturi contentlocation put post undefined servers fielding standards page rfc http11 june contentmd5 contentmd5 entityheader field rfc md5 endtoend message integrity check mic mic accidental modification malicious attacks contentmd5 contentmd5 md5 rfc contentmd5 header field may origin server integrity check origin servers may contentmd5 header field must not endtoend integrity check may digest value header field matches md5 must contentmd5 http rfc mime composite mediatypes eg multipart may mime http contentmd5 contenttransferencoding contentencoding contenttransfer encoding contentencoding contentmd5 transferencoding header field crlf must not must fielding standards page rfc http11 june contentmd5 http rfc mime contentmd5 http mime http mime contenttransferencoding transferencoding contentencoding http uses binary content types mime such cases byte order transmission byte order lastly http text types canonical form crlf contentrange contentrange partial entitybody full entitybody partial body range units contentrange contentrange bytecontentrangespec bytesunit sp byterangerespspec firstbytepos lastbytepos should total length full entitybody byterangesspecifier values must must absolute byte positions bytepos value firstbytepos value instancelength value invalid bytecontentrange must status code requested should contentrange instancelength specifies current length fielding standards page rfc http11 june status code partial content must not contentrange examples bytecontentrangespec values http contentrange contentlength http11 partial date wed nov gmt lastmodified wed nov gmt contentrange contentlength contenttype http multipart message media type compatibility issue must not multipartbyteranges media type may multipartbyteranges media type multipartbyteranges message must not client requests multiple byteranges should fielding standards page rfc http11 june server ignores should invalid range header field normally full entity range requestheader field unsatisfiable range request header field byterangespec values firstbytepos value current length should response code requested satisfiable section requested satisfiable response ok response unsatisfiable range requestheader contenttype contenttype entityheader field media type head media type get contenttype contenttype media contenttype texthtml charsetiso88594 media type date date generalheader field rfc field value httpdate must rfc 8date format date date httpdate date tue nov gmt origin must date header field fielding standards page rfc http11 june response status code continue switching protocols may date header field servers option response status code conveys server error eg internal server error date reasonable approximation current time must not date header field must date header field must date http must not cache responses http should ntp reliable external clients should date header field put post must not date header field httpdate date should not should available approximation accurate date semantic value clockless origin server origin server implementations origin server must not expires modified reliable clock may expires configuration time expires fielding standards page rfc http11 june etag etag responseheader field current value entity tag entity tag may etag etag examples etag etag wxyzzy etag requestheader field server behaviors 100continue expectationextension expectation values must appropriate error status must expectation failed header field extensible syntax future extensions must expectation failed comparison expectation values fielding standards page rfc http11 june http11 must expectation failed must http10 http11 expires expires entityheader field stale cache entry proxy cache user agent cache origin server intermediate cache fresh copy expiration model expires absolute date httpdate must rfc date format expires expires httpdate expires thu dec gmt cachecontrol age directive directive overrides expires http11 must invalid date formats past ie origin server sends expires date header value expiration calculations fielding standards page rfc http11 june origin server sends expires http11 should not expires expires header field date value cachecontrol header field section requestheader field should internet email address human user should rfc rfc header field may should not insecure form access protection accepts responsibility particular robot agents should internet email address may internet original issuers address should should not header field users privacy interests sites security policy host host requestheader field specifies internet uri http url fielding standards page rfc http11 june host field value must origin server url origin server urls url multiple host names ip host host host port section port information implies http url origin server get http11 host must host header field http11 uri internet host header field must empty value http11 must request message host internetbased http11 must request status code http11 request message host host ifmatch ifmatch requestheader field entity tags ifmatch header field entity efficient updates transaction overhead inadvertent modification wrong version special case current entity ifmatch ifmatch entity tags entity tag get ifmatch fielding standards page rfc http11 june current entity exists may ifmatch header field must strong comparison function entity tags ifmatch entity tags entity exists must not must precondition failed put ifmatch header field result ifmatch must ifmatch should origin server vary must not resource eg put may ifmatch header field request method must not ifmatch entity tag examples ifmatch ifmatch xyzzy r2d2xxxx c3piozzzz ifmatch ifmatch header field ifnonematch ifmodifiedsince header fields ifmodifiedsince ifmodifiedsince requestheader field ifmodifiedsince ifmodifiedsince httpdate fielding standards page rfc http11 june ifmodifiedsince sat oct gmt get ifmodifiedsince range header ifmodifiedsince ok status ifmodifiedsince get current time ifmodifiedsince get modifiedsince should modified efficient updates transaction overhead range requestheader field modifies modifiedsince full details ifmodifiedsince ifmodifiedsince header field exact date comparison function lessthan function modified modifiedsince header field cache validation clients exact date string modified header field whenever client uses arbitrary date ifmodifiedsince lastmodified servers understanding different encodings race conditions ifmodifiedsince subsequent request fielding standards page rfc http11 june ifmodified clients clock servers clock corrections different time bases ifmodifiedsince header field ifmatch ifunmodifiedsince header fields ifnonematch ifnonematch requestheader field entity tags ifnonematch header field efficient updates transaction overhead method eg put special case value matches current entity ifnonematch ifnonematch entity tags entity tag get ifnonematch current entity exists must not resources modification date ifmodifiedsince header field request method get head should modified header fields etag request methods must precondition failed entities tags weak comparison function get head fielding standards page rfc http11 june entity tags may ifnonematch header field must ifmodifiedsince header fields entity tags must not modified ifnonematch header field result ifnonematch must server behavior ifmodifiedsince ifnonematch ifnonematch must not origin server vary should put examples ifnonematch ifnonematch wxyzzy ifnonematch xyzzy r2d2xxxx c3piozzzz ifnonematch wxyzzy wr2d2xxxx wc3piozzzz ifnonematch ifnonematch header field ifmatch ifunmodifiedsince header fields ifrange partial copy uptodate copy entire entity range requestheader get ifunmodifiedsince ifmatch ifrange informally ifrange ifrange httpdate fielding standards page rfc http11 june entity tag modified may ifrange httpdate ifrange should range header must range header subrange operation entity tag ifrange header matches entity tag should partial entity tag should entire entity ok response ifunmodifiedsince ifunmodifiedsince requestheader field should ifunmodifiedsince must not must precondition failed ifunmodifiedsince ifunmodifiedsince httpdate ifunmodifiedsince sat oct gmt ifunmodifiedsince ifunmodifiedsince should ifunmodifiedsince ifnonematch ifmodifiedsince lastmodified lastmodified entityheader field origin server lastmodified lastmodified httpdate fielding standards page rfc http11 june lastmodified tue nov gmt exact meaning header field origin server original resource file system lastmodify times component parts lastupdate time stamp virtual objects internal state origin server must not lastmodified servers time message origination such cases must origination date origin server should lastmodified date accurate assessment entitys modification time entity changes http11 should lastmodified location location responseheader field requesturi new resource created location new resource 3xx responses should uri automatic redirection field value uri location location location contentlocation header field section location contentlocation header fields location contentlocation fielding standards page rfc http11 june maxforwards maxforwards requestheader field trace options inbound server request chain maxforwards maxforwards maxforwards decimal integer request message gateway recipient trace options maxforwards header field must must not must final recipient maxforwards must maxforwards maxforwards header field may method definition pragma pragma generalheader field specific directives requestresponse chain pragma directives specify optional may pragma pragma nocache extensionpragma nocache directive request message should origin server nocache cachedirective backward compatibility http10 clients should header fields http11 fielding standards page rfc http11 june pragma must application regardless requestresponse chain specific recipient pragma directive should http11 should pragma cachecontrol pragma http pragma header field reliable replacement cachecontrol proxyauthenticate proxyauthenticate responseheader field must proxy authentication required field value authentication scheme requesturi proxyauthenticate proxyauthenticate http access authentication process http authentication digest access authentication wwwauthenticate proxyauthenticate header field applies current connection should not intermediate proxy proxyauthenticate header field proxyauthorization proxyauthorization requestheader field proxyauthorization field value authentication information proxy andor realm proxyauthorization proxyauthorization http access authentication process http authentication digest access authentication authorization proxyauthorization header field applies outbound proxy proxy authenticate multiple proxies fielding standards page rfc http11 june proxyauthorization header field may client request byte ranges http http byte range http servers need support byte range operations byte range specifications http byte range operation may rangesspecifier byterangesspecifier byterangesspecifier bytesunit byterangeset byterangespec suffixbyterangespec byterangespec firstbytepos lastbytepos firstbytepos value lastbytepos value byte lastbytepos value must invalid byterangespec must header field lastbytepos value current length entitybody lastbytepos current length fielding standards page rfc http11 june suffixbyterangespec suffixlength suffixlength 1digit suffixlength value form specifies valid byterangeset current length zero suffixlength otherwise should requested otherwise should partial content examples byterangesspecifier values bytes byte offsets bytes byte offsets bytes byte offsets only bytes canonical specifications bytes byte offsets retrieval http retrieval requests get may entire entity range request header range range rangesspecifier fielding standards page rfc http11 june may range header http11 intermediate caches support byte range supports efficient recovery efficient partial retrieval server supports range header range header get get status code partial content range header get ifmodifiedsince ifnonematch ifunmodifiedsince ifmatch get modified ifrange range header range request forwards inbound server entire entity should should cache allocation policies referer referersic requestheader field servers benefit uri requesturi header field referer referer must not requesturi uri user keyboard referer referer absoluteuri relativeuri example referer fielding standards page rfc http11 june field value uri should requesturi uri must not security considerations retryafter retryafter responseheader field unavailable response may redirection minimum time httpdate integer number retryafter retryafter httpdate retryafter fri dec gmt retryafter server server responseheader field contains information origin server multiple product tokens section significant subproducts server server product comment example server cern30 must not server should via revealing specific software version server machine security holes server fielding standards page rfc http11 june te te requestheader field trailer fields keyword trailers andor te te tcodings trailers transferextension acceptparams keyword trailers trailer fields examples te te te trailers deflateq05 te header field immediate connection must field section te http11 server tests te keyword trailers trailer fields trailer fields http11 entire response te fielding standards page rfc http11 june multiple transfercodings nonzero qvalue te te trailer trailer general field value header fields trailer trailer http11 should trailer header field nonempty trailer doing header fields trailer header field should not header fields trailer fields message header fields trailer header field must not header fields transferencoding contentlength trailer transferencoding transferencoding generalheader field message body transferencoding transferencoding transfercodings transferencoding fielding standards page rfc http11 june multiple encodings must additional may entityheader fields http10 transfer encoding upgrade upgrade additional communication protocols switch protocols must upgrade header field switching protocols upgrade upgrade upgrade http20 shttp13 irc69 rtax11 upgrade header field simple mechanism http11 incompatible protocol http major version current request http11 difficult transition incompatible protocols method andor upgrade header field transportlayer connection upgrade applicationlayer communication new protocol must http upgrade header field upgrade header field immediate connection upgrade keyword must header field section upgrade http11 fielding standards page rfc http11 june upgrade header field different connection redirection response protocol name http hypertext transfer protocols http version rules future updates protocol name useragent useragent requestheader field contains information user agent statistical purposes protocol violations particular user agent limitations user should multiple product tokens section significant part user agent product tokens useragent useragent product comment example useragent cernlinemode215 vary vary field value requestheader fields subsequent request stale responses vary field value advises user agent vary field value request headers appropriate representation vary header field vary vary http11 should vary header field cacheable response serverdriven negotiation doing future requests user agent fielding standards page rfc http11 june may vary header field noncacheable response serverdriven negotiation user agent useful information response varies vary field value fieldnames signals only requestheader field values appropriate representation may future requests field names requestheader fields specification field names vary field value unspecified parameters requestheaders eg network address client play response representation must not proxy server origin server via via generalheader field must intermediate protocols origin server received rfc message forwards request loops protocol capabilities requestresponse chain via via receivedprotocol receivedby comment receivedprotocol protocolname protocolversion host port pseudonym protocol version requestresponse chain receivedprotocol version via field value protocol capabilities upstream applications fielding standards page rfc http11 june http receivedby field optional port number recipient server real host sensitive information may may default port multiple via field values must end result comments may via header field recipient proxy gateway analogous useragent server header fields via may request message http10 internal proxy http11 public proxy origin server via header field via apache11 proxies network firewall should not firewall region should receivedby host should appropriate pseudonym strong privacy requirements internal structures may via header field entries identical receivedprotocol values such entry via via fielding standards page rfc http11 june applications should not multiple entries organizational control applications must not different receivedprotocol values warning warning generalheader field possible lack semantic transparency entity body warning warning warning warningvalue warncode sp sp sp warnagent host port pseudonym warning httpdate may warning should natural language human user may available knowledge acceptlanguage contentlanguage response etc english default character iso88591 iso88591 must rfc warning specific warncodes response messages warning should warning must not warning cache entry should warning fielding standards page rfc http11 june warning must warning warning recent relevant response warning user agent should warnings warnings systems warning should user agent behavior requirements warnings english must revalidation must cache returns stale response disconnected should heuristic must responses age miscellaneous warning text may arbitrary information human user must not action besides fielding standards page rfc http11 june transformation must intermediate cache contentencoding contenttype warning miscellaneous persistent warning warning text may arbitrary information human user must not implementation sends warning http10 must date must bad consequences warning header fields warning must wwwauthenticate wwwauthenticate responseheader field must unauthorized response messages field value authentication schemes requesturi wwwauthenticate wwwauthenticate http access authentication process http authentication digest access authentication user special care www authenticate field value wwwauthenticate header field authentication parameters considerations application developers information security limitations http11 definitive solutions security risks fielding standards page rfc http11 june personal information http large amounts personal information users name location address passwords encryption keys etc should http convenient interface such information history serious security andor privacy problems adverse publicity implementors company abuse server log information personal data reading patterns certain countries people http such material transfer sensitive information generic data http particular piece should header fields server via referer revealing specific software version server machine security holes implementors should server header field configurable option proxies network firewall should special precautions header information should via referer reading patterns user details fielding standards page rfc http11 june referer personal information referer private documents uri privacy interests sites security policy should not must user preference application defaults configuration convenient toggle interface referer useragent server specific client particular security hole http encoding sensitive information uris private information private information source referer browser client toggle switch referer clients should not referer header field http authors http should not get sensitive data requesturi servers proxies user agents uri servers postbased form submission privacy issues connected accept headers accept acceptlanguage particular languages fielding standards page rfc http11 june particular ethnic group user acceptlanguage configuration process user agent acceptlanguage acceptlanguage vary responseheader fields elaborate header fields quality values user identifiers such user content providers content providers individual users network address user agent privacy user agents header configuration options extreme privacy measure proxies general purpose user agents high degree should based file path names implementations http origin servers should http server administrators http http uris file system calls must special care http unix microsoft windows path component directory level http must such construct requesturi http similarly access control files configuration files script code must inappropriate retrieval experience minor bugs http security risks fielding standards page rfc http11 june dns spoofing clients http domain name security attacks ip dns clients ip numberdns name http should name resolver ip numberdns name association previous host name lookups cache host name lookups should ttl live name server http clients cache host name lookups performance improvement must ttl dns http ip address changes observing potential security vulnerability dns location headers spoofing server supports multiple organizations must location content location invalidate resources contentdisposition issues rfc contentdisposition http serious security considerations contentdisposition http rfc rfc fielding standards page rfc http11 june authentication credentials idle clients existing http user agents http11 direct clients significant defect http circumstances applications security model clients applications session termination indication server side separate study password protection screen savers idle timeouts security problems particular user agents cache credentials accessible mechanism user control proxies caching http maninthemiddle attacks compromise serious security privacy problems proxies personal information individual users proprietary information content providers privacy considerations wide range potential attacks proxy particular log information sensitive personal information andor information log appropriate guidelines fielding standards page rfc http11 june caching additional potential vulnerabilities attractive target malicious exploitation cache contents persist http cache contents sensitive information proxy configuration options proxy operators default configuration users proxy need http broad range privacy attacks http11 denial proxies beware acknowledgments heavy use bnf david h crocker rfc similarly nathaniel borenstein ned freed mime past confusion http internet message formats http active developer communitythe http worldwide web marc andreessen robert cailliau daniel connolly bob denny john franks jeanfrancois groff phillip hallambaker hakon lie ari luotonen rob mccool lou montulli dave raggett tony sanders marc vanheyningen special recognition early aspects httpwg fielding standards page rfc http11 june gary adams ross patterson harald tveit alvestrand albert lunde keith ball john mallery brian behlendorf jeanphilippe martinflatin paul burchard mitra maurizio codogno david morris mike cowlishaw gavin nicol czyborra bill perry michael dolan jeffrey perry david j fiander scott powers alan freier owen rees marc hedlund luigi rizzo greg herlihy david robinson koen holtman marc salomon alex hopmann rich salz bob jernigan allan schiffman shel kaphan jim seidman rohit khare chuck shotton john klensin eric sink martijn koster simon e spero alexei kosut richard n taylor david kristol robert thau daniel laliberte bill bearheart weinman ben laurie francois yergeau paul j leach mary ellen zurko daniel dubois josh cohen shel kaphan paul leach koen holtman david morris larry masinter ari luotonen john franks additional input steve zilles thanks cave men palo alto jim gettys current editor document wishes roy fielding previous editor john klensin jeff mogul paul leach dave kristol koen holtman john franks josh cohen alex hopmann scott lawrence larry masinter jeff mogul scott lawrence mustmayshould fielding standards page rfc http11 june apache anselm bairdsmith jigsaw henrik frystyk rfc document attempts references alvestrand h tags identification languages rfc march anklesaria mccahill lindner p johnson d torrey alberti internet gopher protocol document search retrieval protocol rfc march bernerslee t universal resource identifiers www rfc june bernerslee t masinter mccahill uniform resource locators url rfc december bernerslee t d connolly hypertext markup language rfc november bernerslee t fielding r h frystyk hypertext transfer protocol http10 rfc may freed n n borenstein multipurpose internet extensions mime part format internet message bodies rfc november braden r requirements internet hosts communication layers std rfc october crocker d format arpa internet text messages std rfc august davis kahle morris h salem j shen t wang r sui j grinbaum wais interface protocol prototype functional specification thinking machines april fielding r relative uniform resource locators rfc june horton r adams interchange usenet messages rfc december fielding standards page rfc http11 june kantor p lapsley network transfer protocol rfc february moore k mime multipurpose internet extensions part message header extensions nonascii text rfc november nebel e masinter formbased file upload html rfc november postel j simple transfer protocol std rfc august postel j media type registration procedure rfc november postel j j reynolds file transfer protocol std rfc october reynolds j j postel assigned numbers std rfc october sollins k masinter functional requirements uniform resource names rfc december usascii coded character set code information interchange ansi x341986 ansi iso8859 information processing singlebyte coded graphic character sets part latin alphabet iso885911987 part latin alphabet iso88592 part latin alphabet iso88593 part latin alphabet iso88594 part latincyrillic iso88595 part latinarabic iso88596 part latingreek iso88597 part latinhebrew iso88598 part latin alphabet iso88599 meyers j rose contentmd5 header rfc october carpenter y rekhter renumbering needs rfc february deutsch p gzip file format specification version rfc may fielding standards page rfc http11 june venkata n padmanabhan jeffrey mogul improving http latency computer networks isdn systems dec slightly proc www mosaic web oct joe touch john heidemann katia obraczka analysis http performance url isi research report isirr98463 original report aug uscinformation august mills d network protocol version specification analysis rfc march deutsch p deflate compressed data format specification rfc may spero analysis http performance problems deutsch p j gailly zlib compressed data format specification rfc may franks j hallambaker p hostetler j leach p luotonen sink e stewart http digest access authentication rfc january fielding r gettys j mogul j frystyk h bernerslee hypertext transfer protocol http11 rfc january bradner key rfcs indicate requirement levels bcp rfc march troost r dorner communicating presentation information internet messages contentdisposition header rfc june mogul j fielding r gettys j h frystyk interpretation http version numbers rfc may palme j internet message headers rfc february fielding standards page rfc http11 june yergeau utf8 transformation format unicode iso10646 rfc january nielsen hf gettys j bairdsmith prudhommeaux e lie h lilley network performance effects http11 css1 png proceedings acm sigcomm cannes france september freed n n borenstein multipurpose internet extensions mime part media types rfc november alvestrand h ietf policy character sets languages bcp rfc january bernerslee t fielding r masinter uniform resource identifiers uri generic syntax semantics rfc august franks j hallambaker p hostetler j lawrence leach p luotonen sink e stewart http authentication digest access authentication rfc june luotonen tunneling tcp web servers work progress jg647 palme j hopmann mime email encapsulation aggregate documents html mhtml rfc march bradner internet standards process revision bcp rfc october masinter hyper text coffee pot protocol htcpcp10 rfc april freed n n borenstein multipurpose internet extensions mime part conformance criteria examples rfc november troost r dorner k moore communicating presentation information internet messages contentdisposition header field rfc august fielding standards page rfc http11 june authors addresses roy t fielding information computer california irvine irvine ca usa fax email james gettys web consortium mit laboratory computer technology square cambridge ma usa fax email jeffrey mogul western research laboratory compaq computer university avenue palo alto california usa email henrik frystyk nielsen web consortium mit laboratory computer technology square cambridge ma usa fax email larry masinter xerox coyote hill road palo alto ca usa email fielding standards page rfc http11 june paul j leach microsoft microsoft redmond wa usa email tim bernerslee director world web consortium mit laboratory computer technology square cambridge ma usa fax email fielding standards page rfc http11 june appendices internet media type http11 internet media type messagehttp messagehttp type http response message mime message types line length applicationhttp type http response messages iana media type media subtype name required optional version msgtype httpversion message type request encoding only 7bit 8bit security considerations media type media subtype name required optional version msgtype httpversion message type request encoding http binary format use contenttransferencoding email security considerations fielding standards page rfc http11 june internet media type http partial content response message media type multipartbyteranges media type contenttype contentrange boundary parameter specifies boundary string media type media subtype name required optional encoding only 7bit 8bit security considerations http11 partial content date wed nov gmt lastmodified wed nov gmt contenttype multipartbyteranges boundarythis_string_separates this_string_separates contenttype contentrange this_string_separates contenttype contentrange this_string_separates notes additional crlfs boundary string fielding standards page rfc http11 june rfc boundary string byteranges specification media type http11 tolerant applications document specifies http11 operational applications deviations whenever clients should statusline requestline should sp ht sp line terminator messageheader fields crlf such headers lf line terminator cr should common denominator character codes usascii iso88591 additional potential problems date encodings http11 should rfc850 http11 may expires proper value must not expires proper value must gmt local time zone must not expiration time fielding standards page rfc http11 june http date value gmt must gmt conservative possible conversion differences http entities rfc entities http11 internet rfc multipurpose internet extensions mime open variety extensible mechanisms rfc http rfc optimize performance binary connections new media types date comparisons http specific areas http rfc proxies mime should appropriate conversions proxies mime http mimeversion http mimecompliant http11 may mimeversion generalheader field mime mimeversion header field full compliance mime rfc proxiesgateways full compliance http mime mimeversion mimeversion 1digit 1digit mime http11 http11 mime canonical form rfc internet canonical form rfc text media type http rfc crlf cr lf fielding standards page rfc http11 june http crlf cr lf text content http http mime should text media rfc canonical form crlf contentencoding http cr lf implementors original content original content canonical form canonical form such checksums http date formats http11 date formats section date comparison proxies should date header field http11 introduction contentencoding rfc http11s contentencoding header field media type proxies http mimecompliant must contenttype experimental applications contenttype internet mediatype parameter contentencoding rfc contenttransferencoding http contenttransferencoding cte rfc proxies mimecompliant http must cte response message http proxies http mimecompliant correct format safe transport fielding standards page rfc http11 june should contenttransferencoding safe transport destination protocol introduction transferencoding http11 transferencoding header field section proxiesgateways must mimecompliant chunksize chunkextension crlf crlf append chunkdata length length + chunksize crlf append entityheader header fields contentlength remove transferencoding mhtml length limitations http share code mhtml mime line length limitations http http long lines mhtml http mhtml line length limitations canonicalization etc http mime header lines additional features rfc rfc document protocol elements http http11 implementors http11 fielding standards page rfc http11 june experimental features experimental deployment http11 contentdisposition title smtp mime rfc contentdisposition contentdisposition responseheader field origin server default filename contentdisposition rfc contentdisposition dispositiontype dispositionparm dispositiontype attachment dispextensiontoken dispositionparm filenameparm dispextensionparm filenameparm filename contentdisposition attachment filenamefnameext user agent should not directory path filenameparm parameter http should terminal component stream contenttype user agent contentdisposition security issues compatibility previous versions protocol specification previous versions http11 previous versions http11 requestline http09 fielding standards page rfc http11 june valid request http09 major version http11 statusline http10 valid response http09 http10 keepalive persistent connections rfc http10 section summarizes major differences http10 http11 simplify multihomed web servers conserve ip addresses servers support host header report host requestheader section http11 uris important changes older http10 onetoone relationship ip ip internet http web ip large operational web ip serious problems internet ip sole purpose specialpurpose domain http urls web fielding standards page rfc http11 june http http10 must host http11 must host servers must request http11 host servers must uris compatibility http10 persistent connections previous implementations persistent connections http10 persistent http10 default behavior http10 experimental implementations persistent connections new facilities http11 keepalive proxy server inbound server keepalive http10 http10 keepalive important use persistent connection old proxy persistent http11 new keyword http10 persistent connections keepalive keepalive rfc rfc disambiguate key word usage rfc rfc clarified error code inbound server failures dns failures section fielding standards page rfc http11 june create etag contentbase simple safe way identical fashion mhtml transfercoding message lengths message lengths sections quality values representation section http version numbers rfc require upgrade requests http10 implementations section charset headers section cachecontrol http11 sections cachecontrol maxage directive responses section full length byterange request full length range request responses fielding standards page rfc http11 june fix unsatisfiable range requests syntactic problems range doesnt status code byte range request document section rewrite message transmission requirements significant impact internet changing http11 http11 future version http1x made retry requests converted continue general requirement 1xx responses modified tcpspecific nontcp transports http require origin server must not continue allow continue request body allow denialofservice attacks status code transmission requirements fixes proxies contentlength clean responses section warnings warning general header put fielding standards page rfc http11 june transfercoding significant problems iana new header field te trailer headers transfer major performance benefit worth fixing te obscure downward interoperability problem authentication trailers http10 patch link unlink previous versions rfc alternates contentversion derivedfrom link uri contentbase header fields previous versions rfc index please postscript rfc index fielding standards page rfc http11 june copyright statement copyright internet reserved above copyright notice such copies copyright notice internet internet internet internet standards english internet as is the internet society and the internet engineering task force disclaims all warranties express or implied including but not limited to any warranty that the use of the information herein will not infringe any rights or any implied warranties of merchantability or fitness for particular purpose acknowledgement funding rfc editor internet fielding standards page html"
strarr = data_str.split(" ");
strlen = len(strarr)
data_per_machine = (int)(strlen/4)

i = 0
A = [] # 1번 라즈베리
B = [] # 2번 라즈베리
C = [] # 3번 라즈베리
D = [] # 클라이언트 노트북

while strlen>i:
    if i < data_per_machine: # 0 1 2
        A.append(strarr[i])
    elif i >= data_per_machine*3: # 9 10 11 12
        D.append(strarr[i])
    elif i >= data_per_machine*2: # 6 7 8
        C.append(strarr[i])
    elif i >= data_per_machine: # 3 4 5
        B.append(strarr[i])

    i += 1

begin = time.time()

s1.send(" ".join(A).encode())
s2.send(" ".join(B).encode())
s3.send(" ".join(C).encode())

dict4 = dict()
for i in D:
    dict4[i] = dict4.get(i, 0) + 1

#msg1 = recv_timeout(s1)
list_str1 = s1.recv(102400)
list_str2 = s2.recv(102400)
list_str3 = s3.recv(102400)

dict1 = list_to_dict(list_str1.decode())
dict2 = list_to_dict(list_str2.decode())
dict3 = list_to_dict(list_str3.decode())

#print(list_str1.decode())

#print(dict1)
#print(dict2)
#print(dict3)
#print(dict4)

dict4 = add_two_dicts(dict4, dict1)
dict4 = add_two_dicts(dict4, dict2)
dict4 = add_two_dicts(dict4, dict3)

s1.close()
s2.close()
s3.close()
#print(msg1)
#print(msg1.decode('ascii'))
#print(msg2.decode('ascii'))
#print(msg3.decode('ascii'))
print(dict4)
end = time.time()
print(end - begin)
# Out:
# Counter({'must': 346, 'http11': 338, 'rfc': 300, 'field': 270, 'header': 269, 'should': 255, 'http': 241, 'server': 238, 'may': 187, 'fielding': 184, 'request': 181, 'standards': 181, 'june': 180, 'page': 176, 'origin': 173, 'not': 170, 'cache': 142, 'response': 142, 'user': 133, 'fields': 116, 'entity': 114, 'status': 96, 'message': 92, 'value': 92, 'media': 86, 'agent': 79, 'type': 75, 'section': 73, 'date': 72, 'uri': 70, 'code': 69, 'http10': 67, 'directive': 65, 'requesturi': 64, 'protocol': 64, 'content': 62, 'cachecontrol': 60, 'servers': 60, 'get': 60, 'information': 59, 'internet': 57, 'expiration': 57, 'entry': 51, 'warning': 51, 'proxy': 49, 'range': 48, 'authentication': 47, 'host': 46, 'new': 45, 'method': 44, 'requestheader': 43, 'responses': 43, 'resource': 43, 'lastmodified': 43, 'time': 42, 'tag': 42, 'multiple': 40, 'expires': 40, 'version': 39, 'client': 37, 'headers': 37, 'sp': 37, 'mime': 37, 'crlf': 37, 'clients': 36, 'age': 36, 'current': 35, 'error': 35, 'requ
# ...
